# %%
import pandas as pd
import numpy as np
import random

# %%
# df = pd.read_csv("/media/anubhav/New Volume/vidhaan/data_gen/Case-2022-08-26 (1).csv")
df = pd.read_csv("F:/vidhaan/advocate_performance/dataset_advocate_performance.csv")

# %%
del df['Unnamed: 0'],df['id']

# %%
del df['age']

# %%
del df['active cases']

# %%
df['case_type'] = df['speciality']

# %%
del df['speciality']

# %%
df.head()
# Out:
#           name  experience (yrs)    fees  avg resolve time (days)  \
# 0        misri              15.0  156290                      618
# 1         tina              30.0  307280                      598
# 2  dharmendera              14.0  145938                      577
# 3         sukh              10.0  105270                      494
# 4        mairy              12.0  125168                      566
#
#                               case_type
# 0  Petition for Special Leave to Appeal
# 1                         Original Suit
# 2             Contempt Petition (Civil)
# 3                  Arbitration Petition
# 4             Transferred Case Petition

# %%
del df['experience (yrs)'],df['avg resolve time (days)']

# %%
df['state'] = np.nan
df['court'] = np.nan
df['petitioner'] = np.nan
df['respondent'] = 'University Grants Commission'
df['case_stage'] = np.nan

# %%
df.head()
# Out:
#           name    fees                             case_type  state  court  \
# 0        misri  156290  Petition for Special Leave to Appeal    NaN    NaN
# 1         tina  307280                         Original Suit    NaN    NaN
# 2  dharmendera  145938             Contempt Petition (Civil)    NaN    NaN
# 3         sukh  105270                  Arbitration Petition    NaN    NaN
# 4        mairy  125168             Transferred Case Petition    NaN    NaN
#
#    petitioner                    respondent  case_stage
# 0         NaN  University Grants Commission         NaN
# 1         NaN  University Grants Commission         NaN
# 2         NaN  University Grants Commission         NaN
# 3         NaN  University Grants Commission         NaN
# 4         NaN  University Grants Commission         NaN

# %%
df.drop([0,1,2,3])
# Out:
#             name    fees                     case_type  state  court  \
# 4          mairy  125168     Transferred Case Petition    NaN    NaN
# 5           sube  276080  Contempt Petition (Criminal)    NaN    NaN
# 6        mangala  347244      Criminal Appeal Petition    NaN    NaN
# 7          soona  235322     Contempt Petition (Civil)    NaN    NaN
# 8         bhemji  316519     Transferred Case Petition    NaN    NaN
# ...          ...     ...                           ...    ...    ...
# 6481      sahbaj  365792          Arbitration Petition    NaN    NaN
# 6482    davendra  156170                 Original Suit    NaN    NaN
# 6483     marzina  206280                 Writ Petition    NaN    NaN
# 6484       bulet  336518     Transferred Case Petition    NaN    NaN
# 6485  nizamuddin  145798          Arbitration Petition    NaN    NaN
#
#       petitioner                    respondent  case_stage
# 4            NaN  University Grants Commission         NaN
# ...

# %%
types_of_cases = ["Civil (Appeal) Petition","Contempt Petition (Civil)","Writ Petition"]

# %%
types_of_court = ['Supreme Court','High Court','District Court','Lower Court']

# %%
stage_of_cases = ['Ongoing','Disposed']

# %%
states = ["Andhra Pradesh","Arunachal Pradesh" ,"Assam","Bihar","Chhattisgarh","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telangana","Tripura","Uttar Pradesh","Uttarakhand","West Bengal","Andaman and Nicobar Islands","Chandigarh","Dadra and Nagar Haveli","Daman and Diu","Lakshadweep","Delhi","Puducherry"]

# %%
# states = ['Chhattisgarh','Rajasthan','Punjab','Uttar Pradesh','Haryana','Delhi','Karnataka','Tamil Nadu','Maharashtra','Madhya Pradesh','Gujrat','Telangana']

# %%
d = pd.DataFrame()

# %%
for i in range(len(df)):
    df['state'][i] = random.choice(states)
    df['court'][i] = random.choice(types_of_court)
    df['case_stage'][i] = random.choice(stage_of_cases)
# Out:
# C:\Users\AK-47\AppData\Local\Temp/ipykernel_13068/2630004742.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['state'][i] = random.choice(states)
# C:\Users\AK-47\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# C:\Users\AK-47\AppData\Local\Temp/ipykernel_13068/2630004742.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df['coram'] = df['fees']

# %%
del df['fees']

# %%
df['coram'] = (df['coram']*2).astype(int)

# %%
df.head()
# Out:
#           name                             case_type              state  \
# 0        misri  Petition for Special Leave to Appeal         Chandigarh
# 1         tina                         Original Suit         Puducherry
# 2  dharmendera             Contempt Petition (Civil)                Goa
# 3         sukh                  Arbitration Petition              Delhi
# 4        mairy             Transferred Case Petition  Jammu and Kashmir
#
#             court  petitioner                    respondent case_stage   coram
# 0     Lower Court         NaN  University Grants Commission   Disposed  312580
# 1      High Court         NaN  University Grants Commission    Ongoing  614560
# 2  District Court         NaN  University Grants Commission    Ongoing  291876
# 3      High Court         NaN  University Grants Commission    Ongoing  210540
# 4   Supreme Court         NaN  University Grants Commission   Disposed  250336

# %%
df['bench'] = np.nan

# %%
for i in range(len(df)):
    df['bench'][i] = random.choice(['Single bench','Single bench','Single bench','Two judge bench'])
# Out:
# C:\Users\AK-47\AppData\Local\Temp/ipykernel_13068/1256552179.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['bench'][i] = random.choice(['Single bench','Single bench','Single bench','Two judge bench'])
# C:\Users\AK-47\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df.head()
# Out:
#           name                             case_type              state  \
# 0        misri  Petition for Special Leave to Appeal         Chandigarh
# 1         tina                         Original Suit         Puducherry
# 2  dharmendera             Contempt Petition (Civil)                Goa
# 3         sukh                  Arbitration Petition              Delhi
# 4        mairy             Transferred Case Petition  Jammu and Kashmir
#
#             court  petitioner                    respondent case_stage  \
# 0     Lower Court         NaN  University Grants Commission   Disposed
# 1      High Court         NaN  University Grants Commission    Ongoing
# 2  District Court         NaN  University Grants Commission    Ongoing
# 3      High Court         NaN  University Grants Commission    Ongoing
# 4   Supreme Court         NaN  University Grants Commission   Disposed
#
#     coram            bench
# 0  312580     Single bench
# 1  614560     Single bench
# ...

# %%
df['case_name'] = np.nan

# %%
for i in range(len(df)):
    df['case_name'][i] = str(df['name'][i])+' vs '+str(df['respondent'][i])
# Out:
# C:\Users\AK-47\AppData\Local\Temp/ipykernel_13068/2804731140.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['case_name'][i] = str(df['name'][i])+' vs '+str(df['respondent'][i])
# C:\Users\AK-47\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df.head()
# Out:
#           name                             case_type              state  \
# 0        misri  Petition for Special Leave to Appeal         Chandigarh
# 1         tina                         Original Suit         Puducherry
# 2  dharmendera             Contempt Petition (Civil)                Goa
# 3         sukh                  Arbitration Petition              Delhi
# 4        mairy             Transferred Case Petition  Jammu and Kashmir
#
#             court  petitioner                    respondent case_stage  \
# 0     Lower Court         NaN  University Grants Commission   Disposed
# 1      High Court         NaN  University Grants Commission    Ongoing
# 2  District Court         NaN  University Grants Commission    Ongoing
# 3      High Court         NaN  University Grants Commission    Ongoing
# 4   Supreme Court         NaN  University Grants Commission   Disposed
#
#     coram            bench                                    case_name
# ...

# %%
df['petitioner'] = df['name']

# %%
del df['name']

# %%
df.head()
# Out:
#                               case_type              state           court  \
# 0  Petition for Special Leave to Appeal         Chandigarh     Lower Court
# 1                         Original Suit         Puducherry      High Court
# 2             Contempt Petition (Civil)                Goa  District Court
# 3                  Arbitration Petition              Delhi      High Court
# 4             Transferred Case Petition  Jammu and Kashmir   Supreme Court
#
#     petitioner                    respondent case_stage   coram  \
# 0        misri  University Grants Commission   Disposed  312580
# 1         tina  University Grants Commission    Ongoing  614560
# 2  dharmendera  University Grants Commission    Ongoing  291876
# 3         sukh  University Grants Commission    Ongoing  210540
# 4        mairy  University Grants Commission   Disposed  250336
#
#              bench                                    case_name
# 0     Single bench        misri vs University Grants Commission
# ...

# %%
df['case_filling_year'] = np.nan

# %%
for i in range(len(df)):
    df['case_filling_year'][i] = int(np.random.randint(low=2011,high=2020))
# Out:
# C:\Users\AK-47\AppData\Local\Temp/ipykernel_13068/2812179737.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['case_filling_year'][i] = int(np.random.randint(low=2011,high=2020))

# %%
df['case_filling_year'] = df['case_filling_year'].astype(int)

# %%
df.head()
# Out:
#                               case_type              state           court  \
# 0  Petition for Special Leave to Appeal         Chandigarh     Lower Court
# 1                         Original Suit         Puducherry      High Court
# 2             Contempt Petition (Civil)                Goa  District Court
# 3                  Arbitration Petition              Delhi      High Court
# 4             Transferred Case Petition  Jammu and Kashmir   Supreme Court
#
#     petitioner                    respondent case_stage   coram  \
# 0        misri  University Grants Commission   Disposed  312580
# 1         tina  University Grants Commission    Ongoing  614560
# 2  dharmendera  University Grants Commission    Ongoing  291876
# 3         sukh  University Grants Commission    Ongoing  210540
# 4        mairy  University Grants Commission   Disposed  250336
#
#              bench                                    case_name  \
# ...

# %%
df.to_json("F:/vidhaan/data_gen/data.json",orient='records')

# %%
df.head()
# Out:
#                               case_type              state           court  \
# 0  Petition for Special Leave to Appeal         Chandigarh     Lower Court
# 1                         Original Suit         Puducherry      High Court
# 2             Contempt Petition (Civil)                Goa  District Court
# 3                  Arbitration Petition              Delhi      High Court
# 4             Transferred Case Petition  Jammu and Kashmir   Supreme Court
#
#     petitioner                    respondent case_stage   coram  \
# 0        misri  University Grants Commission   Disposed  312580
# 1         tina  University Grants Commission    Ongoing  614560
# 2  dharmendera  University Grants Commission    Ongoing  291876
# 3         sukh  University Grants Commission    Ongoing  210540
# 4        mairy  University Grants Commission   Disposed  250336
#
#              bench                                    case_name  \
# ...

# %%
dm = df[df['state']=='Tamil Nadu']

# %%
dm.head()
# Out:
#                      case_type       state           court petitioner  \
# 22   Contempt Petition (Civil)  Tamil Nadu  District Court      atish
# 78           Election Petition  Tamil Nadu     Lower Court   sarvjeet
# 183              Writ Petition  Tamil Nadu   Supreme Court     viccky
# 310       Arbitration Petition  Tamil Nadu   Supreme Court   gulwasha
# 321              Writ Petition  Tamil Nadu  District Court   ravinath
#
#                        respondent case_stage   coram            bench  \
# 22   University Grants Commission    Ongoing  410040     Single bench
# 78   University Grants Commission   Disposed  333008  Two judge bench
# 183  University Grants Commission    Ongoing  171360     Single bench
# 310  University Grants Commission    Ongoing  613300  Two judge bench
# 321  University Grants Commission   Disposed  730576     Single bench
#
#                                     case_name  case_filling_year
# ...

# %%
len(dm)
# Out:
# 185

# %%
class my_dictionary(dict):
 
  # __init__ function
    def __init__(self):
        self = dict()
 
  # Function to add key:value
    def add(self, key, value):
        self[key] = value

# %%
dict_obj = my_dictionary()

# %%
for i in states:
    dict_obj.add(i,len(df[df['state']==i]))

# %%
print(dict_obj)
# Out:
# {'Andhra Pradesh': 176, 'Arunachal Pradesh': 181, 'Assam': 183, 'Bihar': 174, 'Chhattisgarh': 177, 'Goa': 171, 'Gujarat': 183, 'Haryana': 169, 'Himachal Pradesh': 162, 'Jammu and Kashmir': 149, 'Jharkhand': 190, 'Karnataka': 173, 'Kerala': 169, 'Madhya Pradesh': 184, 'Maharashtra': 151, 'Manipur': 194, 'Meghalaya': 152, 'Mizoram': 186, 'Nagaland': 174, 'Odisha': 188, 'Punjab': 181, 'Rajasthan': 203, 'Sikkim': 187, 'Tamil Nadu': 185, 'Telangana': 200, 'Tripura': 183, 'Uttar Pradesh': 226, 'Uttarakhand': 148, 'West Bengal': 162, 'Andaman and Nicobar Islands': 199, 'Chandigarh': 187, 'Dadra and Nagar Haveli': 164, 'Daman and Diu': 231, 'Lakshadweep': 180, 'Delhi': 183, 'Puducherry': 181}
